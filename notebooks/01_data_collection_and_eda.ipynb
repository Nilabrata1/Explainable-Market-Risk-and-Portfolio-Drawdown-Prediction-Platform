# %% [markdown]
# # Data Collection and EDA
# Collect real market data when available, otherwise generate synthetic financial data for offline development.

# %%
from src.data_collection import collect_market_data
df = collect_market_data()
df.head()
