# %% [markdown]
# # Feature Engineering
# Create leakage-safe time-series features and the future 5-day drawdown target.

# %%
from src.feature_engineering import engineer_features
features = engineer_features()
features.head()
