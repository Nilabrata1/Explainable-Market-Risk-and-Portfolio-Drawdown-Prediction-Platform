# %% [markdown]
# # Model Training with MLflow
# Train and compare Random Forest, XGBoost, LightGBM, and CatBoost with a time-based split.

# %%
from src.train import train_models
model, metadata = train_models()
metadata
