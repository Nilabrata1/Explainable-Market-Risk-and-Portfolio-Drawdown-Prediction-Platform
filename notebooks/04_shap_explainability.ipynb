# %% [markdown]
# # SHAP Explainability
# Generate global explainability artifacts and inspect feature importance.

# %%
from src.explain import create_explainability_artifacts
importance = create_explainability_artifacts()
importance.head(10)
